# %% [markdown]
# ## TODO
#
# * -99 to be update as na and deal with missing values
# * file to create sql requests
# * traffic data also processed
# * time series analysis and prediction
# * Location analysis with tableau on traffic data

# %%
import pandas as pd
import numpy as np
import urllib

# %%
meteo = pd.read_csv('meteorology_observation_202001.csv', parse_dates=['DATE_TIME']).sort_values(by='DATE_TIME')

# %%
meteo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53134 entries, 311 to 37279
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATE_TIME                 53134 non-null  datetime64[ns]
#  1   OBSERVATORY_NAME          53134 non-null  object
#  2   SENSOR_TYPE               53134 non-null  object
#  3   MINIMUM_TEMPERATURE       53044 non-null  float64
#  4   MAXIMUM_TEMPERATURE       53044 non-null  float64
#  5   AVERAGE_TEMPERATURE       53044 non-null  float64
#  6   MINIMUM_HUMIDITY          53134 non-null  float64
#  7   MAXIMUM_HUMIDITY          53134 non-null  float64
#  8   AVERAGE_HUMIDITY          53134 non-null  float64
#  9   MINIMUM_WIND              53134 non-null  float64
#  10  MAXIMUM_WIND              53134 non-null  float64
#  11  AVERAGE_WIND              53134 non-null  float64
#  12  MINIMUM_DIRECTIONOFWIND   53134 non-null  int64
# ...

# %%
meteo.describe().T
# Out:
#                             count        mean         std       min  \
# MINIMUM_TEMPERATURE       53044.0    5.912294    2.807348  -7.40000
# MAXIMUM_TEMPERATURE       53044.0    6.577936    2.820318  -4.20000
# AVERAGE_TEMPERATURE       53044.0    6.237472    2.799843  -5.50833
# MINIMUM_HUMIDITY          53134.0   78.472679   17.806068 -99.00000
# MAXIMUM_HUMIDITY          53134.0   82.917722   16.049181 -99.00000
# AVERAGE_HUMIDITY          53134.0   80.738619   16.860793 -99.00000
# MINIMUM_WIND              53134.0   -3.572787   22.711833 -99.00000
# MAXIMUM_WIND              53134.0   -0.631684   23.561551 -99.00000
# AVERAGE_WIND              53134.0   -2.280427   23.075747 -99.00000
# MINIMUM_DIRECTIONOFWIND   53134.0   53.499849   92.305266 -99.00000
# MAXIMUM_DIRECTIONOFWIND   53134.0  250.511876  133.716034 -99.00000
# AVERAGE_DIRECTIONOFWIND   53134.0  142.178684  104.385592 -99.00000
# MINIMUM_PRECIPITATION     53134.0  -19.304408   39.353082 -99.00000
# ...

# %%
meteo
# Out:
#                 DATE_TIME   OBSERVATORY_NAME               SENSOR_TYPE  \
# 311   2020-01-01 00:00:00       SABIHAGOKCEN              ICING_SENSOR
# 52911 2020-01-01 00:00:00      TERKOS_BARAJI  AUTOMATED_WEATHER_SENSOR
# 5995  2020-01-01 00:00:00  HACIOSMAN_SARIYER              ICING_SENSOR
# 11232 2020-01-01 00:00:00    ISTOC_MAHMUTBEY              ICING_SENSOR
# 39645 2020-01-01 00:00:00    CAMLICA_TUNEL_K              ICING_SENSOR
# ...                   ...                ...                       ...
# 12471 2020-01-31 23:00:00           CIFTALAN              ICING_SENSOR
# 37318 2020-01-31 23:00:00         ARNAVUTKOY              ICING_SENSOR
# 37102 2020-01-31 23:00:00  BEYLIKDUZU_H_DERE              ICING_SENSOR
# 26281 2020-01-31 23:00:00            SARIYER  AUTOMATED_WEATHER_SENSOR
# 37279 2020-01-31 23:00:00           ATASEHIR              ICING_SENSOR
#
#        MINIMUM_TEMPERATURE  MAXIMUM_TEMPERATURE  AVERAGE_TEMPERATURE  \
# ...

# %%
meteo.describe(include=object).T
# Out:
#                   count unique                       top   freq
# DATE_TIME         53134    743       2020-01-11 09:00:00     76
# OBSERVATORY_NAME  53134     76              SABIHAGOKCEN    740
# SENSOR_TYPE       53134      2  AUTOMATED_WEATHER_SENSOR  28378

# %%
meteo.columns = [c.lower() for c in meteo.columns]

# %%
meteo['day'] = meteo['date_time'].dt.day
meteo['hour'] = meteo['date_time'].dt.hour

# %%
meteo.groupby(['day','hour'])['average_temperature'].mean()
# Out:
# day  hour
# 1    0       4.246015
#      1       4.232719
#      2       4.151538
#      3       4.183236
#      4       4.376414
#                ...
# 31   19      9.000516
#      20      9.030120
#      21      9.006252
#      22      8.975689
#      23      8.931136
# Name: average_temperature, Length: 743, dtype: float64

# %%
meteo.groupby(['observatory_name'])['average_temperature'].mean().sort_values()
# Out:
# observatory_name
# SELIMPASA_KAVAKLI       3.089763
# CATALCA                 3.769317
# SILIVRI_ORMAN_SAHASI    4.061400
# KARTAL_AYDOS_DAGI       4.499884
# SILE_DARLIK             4.588867
#                           ...
# UMRANIYE                7.656079
# AHL_BAKIRKOY            7.658911
# GOZTEPE                 7.835369
# ESENLER                 7.995231
# SUREYYAPASA             8.098734
# Name: average_temperature, Length: 76, dtype: float64
